# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from data_access.image_repository import get_meta_by_capture, get_image_by_id

# %%
data = get_meta_by_capture("")
# Out:
# pulling from path gs://sacred-reality-201417-mlengine/data/126.json
# pulling from path gs://sacred-reality-201417-mlengine/data/128.json
# pulling from path gs://sacred-reality-201417-mlengine/data/130.json
# pulling from path gs://sacred-reality-201417-mlengine/data/132.json
# pulling from path gs://sacred-reality-201417-mlengine/data/134.json
# pulling from path gs://sacred-reality-201417-mlengine/data/136.json
# pulling from path gs://sacred-reality-201417-mlengine/data/138.json
# pulling from path gs://sacred-reality-201417-mlengine/data/14.json
# pulling from path gs://sacred-reality-201417-mlengine/data/140.json
# pulling from path gs://sacred-reality-201417-mlengine/data/142.json
# ...

# %%
meta = data[0]
meta
# Out:
# {'imageId': 126,
#  'mode': 'user',
#  'steeringAngle': 0,
#  'throttle': 0.19795221090316772}

# %%
image = get_image_by_id('{}'.format(meta['imageId']))
print(image.shape)
plt.imshow(image)
# Out:
# (120, 160, 3)
